# %% [markdown]
# ### Set these Parameters first!

# %%
# Where is the csv file?
Input_Path = 'C:/Users/whittlej/Programs/WPy-3702/notebooks/csv files/CAPIM Sample Points.csv'

# %% [markdown]
# ### Optional Initial Parametes

# %%
# Csv files seperator for input and output files..generally (,) or (|)
Delimiter = ','

# Change to 'c' if you require super fast load times
Engine = 'python'

# %% [markdown]
# ### Then Run this code

# %%
# Importing Libraries
import pandas as pd

DataFrame = pd.read_csv(Input_Path, sep=Delimiter, dtype=object, engine='python')
DataFrame.head()
# Out:
#   SAMO_ID      NAME                                   DESCRIPTION STREET  \
# 0   11723  SPT05233         Olinda Creek - (Sediment) - Site ID:3    NaN
# 1   11722  SPT05232   Fishers Wetland - (Sediment) - Site ID:1272    NaN
# 2   11720  SPT05231  Maribyrnong River - (Sediment) - Site ID:538    NaN
# 3   11718  SPT05230        Yarra River - (Sediment) - Site ID:537    NaN
# 4   11716  SPT05229     Kororoit Creek - (Sediment) - Site ID:536    NaN
#
#   SUBURB STATE POSTCODE COUNTRY  LONGITUDE   LATITUDE COMMENTS  \
# 0    NaN   NaN      NaN     NaN  145.36443  -37.69898      NaN
# 1    NaN   NaN      NaN     NaN  145.34142  -38.51163      NaN
# 2    NaN   NaN      NaN     NaN  144.90843  -37.80363      NaN
# 3    NaN   NaN      NaN     NaN  144.89594  -37.83181      NaN
# 4    NaN   NaN      NaN     NaN  144.85324  -37.85642      NaN
#
#                DATATYPENAME  \
# 0  Water Quality Monitoring
# 1  Water Quality Monitoring
# 2  Water Quality Monitoring
# ...
